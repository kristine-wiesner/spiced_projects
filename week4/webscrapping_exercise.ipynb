# %%
import requests
import re
from collections import Counter

# %%
# 1. retrieve the Berlin Wikipedia page
# 2. check the status code

berlin = "https://en.wikipedia.org/wiki/Berlin"
response = requests.get(berlin)

print(response.status_code)
# Out:
# 200

# %%
# 3. store the html contents of the page

html = response.text

# %%
# 4. write the html contents to a file
with open("berlin.html", "wb") as f:
    f.write(html.encode('utf8'))
    f.close()

# %%
# 5. remove all html tags
text = re.sub(r'<.*?>', '', html)
text
# Out:
# '\n\n\n\nBerlin - Wikipedia\ndocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"YCqfhfV4XDMdOp9RTrW7xQAAAM0","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Berlin","wgTitle":"Berlin","wgCurRevisionId":1006622491,"wgRevisionId":1006622491,"wgArticleId":3354,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 German-language sources (de)","All articles with dead external links","Articles with dead external links from July 2020","Articles with permanently dead external links","Articles with dead external links from November 2020","CS1 maint: multiple names: authors list","Articles with dead external links from July 2019",\n"Webarchive template wayback links","CS1 French-language sources (fr)","Articles with short description","Short description is different from Wikidata","Use American English from October 2020","All Wikipedia articles written in American English","Use dmy dates from September 2020","Coordinates on Wikidata","Articles with hAudio microformats","All articles with unsourced statements","Articles with unsourced statements from April 2019","Articles containing potentially dated statements from 2019","All articles containing potentially dated statements","Articles with unsourced statements from April 2020","Pages using multiple image with manual scaled images","Articles with unsourced statements from June 2020","Articles containing German-language text","Articles with unsourced statements from January 2021","Articles containing potentially dated statements from 2015","Wikipedia articles in need of updating from January 2021","All Wikipedia articles in need of updating",\n"Articles containing potentially dated statements from 2014","Articles containing potentially dated statements from 2011","Pages using Sister project links with hidden wikidata","Pages using Sister project links with default search","Wikipedia articles with BNE identifiers","Wikipedia articles with BNF identifiers","Wikipedia articles with GND identifiers","Wikipedia articles with HDS identifiers","Wikipedia articles with ISNI identifiers","Wikipedia articles with LCCN identifiers","Wikipedia articles with MusicBrainz area identifiers","Wikipedia articles with NARA identifiers","Wikipedia articles with NDL identifiers","Wikipedia articles with NKC identifiers","Wikipedia articles with NLI identifiers","Wikipedia articles with SELIBR identifiers","Wikipedia articles with VIAF identifiers","Wikipedia articles with WORLDCATID identifiers","Wikipedia articles with multiple identifiers","Pages using the Kartographer extension","Berlin","German state capitals","Capitals in Europe",\n"City-states","Members of the Hanseatic League","Populated places established in the 13th century","Turkish communities outside Turkey","1230s establishments in the Holy Roman Empire","1237 establishments in Europe","University towns in Germany"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Berlin","wgRelevantArticleId":3354,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgPopupsConflictsWithRefTooltipsGadget":!0,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgKartographerLiveData":{\n"_5c3cdadd0a60372bea4be4576608aad14b0febba":[{ ...

# %%
# 6. extract words
words = re.findall('[A-Za-z]+', text)
words
# Out:
# ['Berlin',
#  'Wikipedia',
#  'document',
#  'documentElement',
#  'className',
#  'client',
#  'js',
#  'RLCONF',
#  'wgBreakFrames',
#  'wgSeparatorTransformTable',
#  'wgDigitTransformTable',
#  'wgDefaultDateFormat',
#  'dmy',
#  'wgMonthNames',
#  'January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December',
#  'wgRequestId',
#  'YCqfhfV',
#  'XDMdOp',
#  'RTrW',
#  'xQAAAM',
#  'wgCSPNonce',
#  'wgCanonicalNamespace',
#  'wgCanonicalSpecialPageName',
#  'wgNamespaceNumber',
#  'wgPageName',
#  'Berlin',
#  'wgTitle',
#  'Berlin',
#  'wgCurRevisionId',
#  'wgRevisionId',
#  'wgArticleId',
#  'wgIsArticle',
#  'wgIsRedirect',
#  'wgAction',
#  'view',
#  'wgUserName',
#  'null',
#  'wgUserGroups',
#  'wgCategories',
#  'CS',
#  'German',
#  'language',
#  'sources',
#  'de',
#  'All',
#  'articles',
#  'with',
#  'dead',
#  'external',
#  'links',
#  'Articles',
#  'with',
#  'dead',
#  'external',
#  'links',
#  'from',
#  'July',
#  'Articles',
#  'with',
#  'permanently',
#  'dead',
#  'external',
#  'links',
#  'Articles',
#  'with',
#  'dead',
#  'external',
#  'links',
#  'from',
#  'November',
#  'CS',
#  'maint',
#  'multiple',
#  'names',
#  'authors',
#  'list',
#  'Articles',
#  'with',
#  'dead',
#  'external',
#  'links',
#  'from',
#  'July',
#  'Webarchive',
#  'template',
#  'wayback',
#  'links',
#  'CS',
#  'French',
#  'language',
#  'sources',
#  'fr',
#  'Articles',
#  'with',
#  'short',
#  'description',
#  'Short',
#  'description',
#  'is',
#  'different',
#  'from',
#  'Wikidata',
#  'Use',
#  'American',
#  'English',
#  'from',
#  'October',
#  'All',
#  'Wikipedia',
#  'articles',
#  'written',
#  'in',
#  'American',
#  'English',
#  'Use',
#  'dmy',
#  'dates',
#  'from',
#  'September',
#  'Coordinates',
#  'on',
#  'Wikidata',
#  'Articles',
#  'with',
#  'hAudio',
#  'microformats',
#  'All',
#  'articles',
#  'with',
#  'unsourced',
#  'statements',
#  'Articles',
#  'with',
#  'unsourced',
#  'statements',
#  'from',
#  'April',
#  'Articles',
#  'containing',
#  'potentially',
#  'dated',
#  'statements',
#  'from',
#  'All',
#  'articles',
#  'containing',
#  'potentially',
#  'dated',
#  'statements',
#  'Articles',
#  'with',
#  'unsourced',
#  'statements',
#  'from',
#  'April',
#  'Pages',
#  'using',
#  'multiple',
#  'image',
#  'with',
#  'manual',
#  'scaled',
#  'images',
#  'Articles',
#  'with',
#  'unsourced',
#  'statements',
#  'from',
#  'June',
#  'Articles',
#  'containing',
#  'German',
#  'language',
#  'text',
#  'Articles',
#  'with',
#  'unsourced',
#  'statements',
#  'from',
#  'January',
#  'Articles',
#  'containing',
#  'potentially',
#  'dated',
#  'statements',
#  'from',
#  'Wikipedia',
#  'articles',
#  'in',
#  'need',
#  'of',
#  'updating',
#  'from',
#  'January',
#  'All',
#  'Wikipedia',
#  'articles',
#  'in',
#  'need',
#  'of',
#  'updating',
#  'Articles',
#  'containing',
#  'potentially',
#  'dated',
#  'statements',
#  'from',
#  'Articles',
#  'containing',
#  'potentially',
#  'dated',
#  'statements',
#  'from',
#  'Pages',
#  'using',
#  'Sister',
#  'project',
#  'links',
#  'with',
#  'hidden',
#  'wikidata',
#  'Pages',
#  'using',
#  'Sister',
#  'project',
#  'links',
#  'with',
#  'default',
#  'search',
#  'Wikipedia',
#  'articles',
#  'with',
#  'BNE',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'BNF',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'GND',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'HDS',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'ISNI',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'LCCN',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'MusicBrainz',
#  'area',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'NARA',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'NDL',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'NKC',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'NLI',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'SELIBR',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'VIAF',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'WORLDCATID',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'with',
#  'multiple',
#  'identifiers',
#  'Pages',
#  'using',
#  'the',
#  'Kartographer',
#  'extension',
#  'Berlin',
#  'German',
#  'state',
#  'capitals',
#  'Capitals',
#  'in',
#  'Europe',
#  'City',
#  'states',
#  'Members',
#  'of',
#  'the',
#  'Hanseatic',
#  'League',
#  'Populated',
#  'places',
#  'established',
#  'in',
#  'the',
#  'th',
#  'century',
#  'Turkish',
#  'communities',
#  'outside',
#  'Turkey',
#  's',
#  'establishments',
#  'in',
#  'the',
#  'Holy',
#  'Roman',
#  'Empire',
#  'establishments',
#  'in',
#  'Europe',
#  'University',
#  'towns',
#  'in',
#  'Germany',
#  'wgPageContentLanguage',
#  'en',
#  'wgPageContentModel',
#  'wikitext',
#  'wgRelevantPageName',
#  'Berlin',
#  'wgRelevantArticleId',
#  'wgIsProbablyEditable',
#  'wgRelevantPageIsProbablyEditable',
#  'wgRestrictionEdit',
#  'wgRestrictionMove',
#  'wgMediaViewerOnClick',
#  'wgMediaViewerEnabledByDefault',
#  'wgPopupsReferencePreviews',
#  'wgPopupsConflictsWithNavPopupGadget',
#  'wgPopupsConflictsWithRefTooltipsGadget',
#  'wgVisualEditor',
#  'pageLanguageCode',
#  'en',
#  'pageLanguageDir',
#  'ltr',
#  'pageVariantFallbacks',
#  'en',
#  'wgMFDisplayWikibaseDescriptions',
#  'search',
#  'nearby',
#  'watchlist',
#  'tagline',
#  'wgWMESchemaEditAttemptStepOversample',
#  'wgULSCurrentAutonym',
#  'English',
#  'wgNoticeProject',
#  'wikipedia',
#  'wgKartographerLiveData',
#  'c',
#  'cdadd',
#  'a',
#  'bea',
#  'be',
#  'aad',
#  'b',
#  'febba',
#  'type',
#  'ExternalData',
#  'service',
#  'geoshape',
#  'url',
#  'https',
#  'maps',
#  'wikimedia',
#  'org',
#  'geoshape',
#  'getgeojson',
#  'u',
#  'ids',
#  'Q',
#  'properties',
#  'title',
#  'Berlin',
#  'fill',
#  'opacity',
#  'stroke',
#  'ff',
#  'stroke',
#  'width',
#  'fill',
#  'ffffff',
#  'wgCoordinates',
#  'lat',
#  'lon',
#  'wgCentralAuthMobileDomain',
#  'wgEditSubmitButtonLabelPublish',
#  'wgULSPosition',
#  'interlanguage',
#  'wgWikibaseItemId',
#  'Q',
#  'RLSTATE',
#  'ext',
#  'globalCssJs',
#  'user',
#  'styles',
#  'ready',
#  'site',
#  'styles',
#  'ready',
#  'noscript',
#  'ready',
#  'user',
#  'styles',
#  'ready',
#  'ext',
#  'globalCssJs',
#  'user',
#  'ready',
#  'user',
#  'ready',
#  'user',
#  'options',
#  'loading',
#  'ext',
#  'kartographer',
#  'style',
#  'ready',
#  'ext',
#  'cite',
#  'styles',
#  'ready',
#  'mediawiki',
#  'page',
#  'gallery',
#  'styles',
#  'ready',
#  'skins',
#  'vector',
#  'styles',
#  'legacy',
#  'ready',
#  'jquery',
#  'makeCollapsible',
#  'styles',
#  'ready',
#  'ext',
#  'visualEditor',
#  'desktopArticleTarget',
#  'noscript',
#  'ready',
#  'ext',
#  'uls',
#  'interlanguage',
#  'ready',
#  'ext',
#  'wikimediaBadges',
#  'ready',
#  'wikibase',
#  'client',
#  'init',
#  'ready',
#  'RLPAGEMODULES',
#  'ext',
#  'kartographer',
#  'staticframe',
#  'ext',
#  'cite',
#  'ux',
#  'enhancements',
#  'mediawiki',
#  'page',
#  'gallery',
#  'site',
#  'mediawiki',
#  'page',
#  'ready',
#  'jquery',
#  'makeCollapsible',
#  'mediawiki',
#  'toc',
#  'skins',
#  'vector',
#  'legacy',
#  'js',
#  'ext',
#  'gadget',
#  'ReferenceTooltips',
#  'ext',
#  'gadget',
#  'charinsert',
#  'ext',
#  'gadget',
#  'extra',
#  'toolbar',
#  'buttons',
#  'ext',
#  'gadget',
#  'refToolbar',
#  'ext',
#  'gadget',
#  'switcher',
#  'ext',
#  'centralauth',
#  'centralautologin',
#  'mmv',
#  'head',
#  'mmv',
#  'bootstrap',
#  'autostart',
#  'ext',
#  'popups',
#  'ext',
#  'visualEditor',
#  'desktopArticleTarget',
#  'init',
#  'ext',
#  'visualEditor',
#  'targetLoader',
#  'ext',
#  'eventLogging',
#  'ext',
#  'wikimediaEvents',
#  'ext',
#  'navigationTiming',
#  'ext',
#  'uls',
#  'compactlinks',
#  'ext',
#  'uls',
#  'interface',
#  'ext',
#  'cx',
#  'eventlogging',
#  'campaigns',
#  'ext',
#  'centralNotice',
#  'geoIP',
#  'ext',
#  'centralNotice',
#  'startUp',
#  'RLQ',
#  'window',
#  'RLQ',
#  'push',
#  'function',
#  'mw',
#  'loader',
#  'implement',
#  'user',
#  'options',
#  'hzgi',
#  'function',
#  'jQuery',
#  'require',
#  'module',
#  'nomin',
#  'mw',
#  'user',
#  'tokens',
#  'set',
#  'patrolToken',
#  'watchToken',
#  'csrfToken',
#  'Berlin',
#  'From',
#  'Wikipedia',
#  'the',
#  'free',
#  'encyclopedia',
#  'Jump',
#  'to',
#  'navigation',
#  'Jump',
#  'to',
#  'search',
#  'Capital',
#  'and',
#  'largest',
#  'city',
#  'of',
#  'Germany',
#  'This',
#  'article',
#  'is',
#  'about',
#  'the',
#  'German',
#  'city',
#  'For',
#  'other',
#  'uses',
#  'see',
#  'Berlin',
#  'disambiguation',
#  'Capital',
#  'city',
#  'and',
#  'state',
#  'in',
#  'GermanyBerlinCapital',
#  'city',
#  'and',
#  'state',
#  'From',
#  'top',
#  'view',
#  'with',
#  'Nicholas',
#  'Quarter',
#  'Rotes',
#  'Rathaus',
#  'and',
#  'the',
#  'Television',
#  'Tower',
#  'Brandenburg',
#  'Gate',
#  'Berlin',
#  'Cathedral',
#  'Charlottenburg',
#  'Palace',
#  'and',
#  'Berlin',
#  'Victory',
#  'Column',
#  'Gendarmenmarkt',
#  'FlagCoat',
#  'of',
#  'arms',
#  'mw',
#  'parser',
#  'output',
#  'locmap',
#  'od',
#  'position',
#  'absolute',
#  'mw',
#  'parser',
#  'output',
#  'locmap',
#  'id',
#  'position',
#  'absolute',
#  'line',
#  'height',
#  'mw',
#  'parser',
#  'output',
#  'locmap',
#  'l',
#  'font',
#  'size',
#  'position',
#  'absolute',
#  'mw',
#  'parser',
#  'output',
#  'locmap',
#  'pv',
#  'line',
#  'height',
#  'position',
#  'absolute',
#  'text',
#  'align',
#  'center',
#  'mw',
#  'parser',
#  'output',
#  'locmap',
#  'pl',
#  'line',
#  'height',
#  'position',
#  'absolute',
#  'top',
#  'em',
#  'text',
#  'align',
#  'right',
#  'mw',
#  'parser',
#  'output',
#  'locmap',
#  'pr',
#  'line',
#  'height',
#  'position',
#  'absolute',
#  'top',
#  'em',
#  'text',
#  'align',
#  'left',
#  'mw',
#  'parser',
#  'output',
#  'locmap',
#  'pv',
#  'div',
#  'display',
#  'inline',
#  'padding',
#  'px',
#  'mw',
#  'parser',
#  'output',
#  'locmap',
#  'pl',
#  'div',
#  'display',
#  'inline',
#  'padding',
#  'px',
#  'float',
#  'right',
#  'mw',
#  'parser',
#  'output',
#  'locmap',
#  'pr',
#  'div',
#  'display',
#  'inline',
#  'padding',
#  'px',
#  'float',
#  'left',
#  'BerlinLocation',
#  'within',
#  'GermanyShow',
#  'map',
#  'of',
#  'GermanyBerlinBerlin',
#  'Europe',
#  'Show',
#  'map',
#  'of',
#  'EuropeCoordinates',
#  'mw',
#  'parser',
#  'output',
#  'geo',
#  'default',
#  'mw',
#  'parser',
#  'output',
#  'geo',
#  'dms',
#  'mw',
#  'parser',
#  'output',
#  'geo',
#  'dec',
#  'display',
#  'inline',
#  'mw',
#  'parser',
#  'output',
#  'geo',
#  'nondefault',
#  'mw',
#  'parser',
#  'output',
#  'geo',
#  'multi',
#  'punct',
#  'display',
#  'none',
#  'mw',
#  'parser',
#  'output',
#  'longitude',
#  'mw',
#  'parser',
#  'output',
#  'latitude',
#  'white',
#  'space',
#  'nowrap',
#  'N',
#  'E',
#  'xfeff',
#  'xfeff',
#  'N',
#  'E',
#  'xfeff',
#  'Coordinates',
#  'N',
#  'E',
#  'xfeff',
#  'xfeff',
#  'N',
#  'E',
#  'xfeff',
#  'Country',
#  'GermanyStateBerlinGovernment',
#  'BodyAbgeordnetenhaus',
#  'of',
#  'Berlin',
#  'Governing',
#  'MayorMichael',
#  'M',
#  'ller',
#  'SPD',
#  'Area',
#  'City',
#  'State',
#  'km',
#  'sq',
#  'mi',
#  'Elevation',
#  'm',
#  'ft',
#  'Population',
#  'December',
#  'City',
#  'State',
#  'Urban',
#  'Metro',
#  'DemonymsBerliner',
#  's',
#  'English',
#  'Berliner',
#  'm',
#  'Berlinerin',
#  'f',
#  'German',
#  'Time',
#  'zoneUTC',
#  'CET',
#  'Summer',
#  'DST',
#  'UTC',
#  'CEST',
#  'Area',
#  'code',
#  's',
#  'GeocodeNUTS',
#  'Region',
#  'DE',
#  'ISO',
#  'codeDE',
#  'BEVehicle',
#  'registrationB',
#  'note',
#  'GRP',
#  'nominal',
#  'billion',
#  'GRP',
#  'per',
#  'capita',
#  'GeoTLD',
#  'berlinHDI',
#  'very',
#  'high',
#  'th',
#  'of',
#  'Websitewww',
#  'berlin',
#  'de',
#  'en',
#  'Berlin',
#  'b',
#  'r',
#  'l',
#  'n',
#  'German',
#  'b',
#  'li',
#  'n',
#  'listen',
#  'is',
#  'the',
#  'capital',
#  'and',
#  'largest',
#  'city',
#  'of',
#  'Germany',
#  'by',
#  'both',
#  'area',
#  'and',
#  'population',
#  'Its',
#  'inhabitants',
#  'as',
#  'of',
#  'December',
#  'make',
#  'it',
#  'the',
#  'most',
#  'populous',
#  'city',
#  'of',
#  'the',
#  'European',
#  'Union',
#  'according',
#  'to',
#  'population',
#  'within',
#  'city',
#  'limits',
#  'One',
#  'of',
#  'Germany',
#  's',
#  'constituent',
#  'states',
#  'Berlin',
#  'is',
#  'surrounded',
#  'by',
#  'the',
#  'state',
#  'of',
#  'Brandenburg',
#  'and',
#  'contiguous',
#  'with',
#  'Potsdam',
#  'Brandenburg',
#  's',
#  'capital',
#  'Berlin',
#  's',
#  'urban',
#  'area',
#  'has',
#  'a',
#  'population',
#  'of',
#  'around',
#  'million',
#  'and',
#  'is',
#  'the',
#  'second',
#  'most',
#  'populous',
#  'urban',
#  'area',
#  'in',
#  'Germany',
#  'after',
#  'the',
#  'Ruhr',
#  'The',
#  'Berlin',
#  'Brandenburg',
#  'capital',
#  'region',
#  'has',
#  'about',
#  'six',
#  'million',
#  'inhabitants',
#  'and',
#  'is',
#  'Germany',
#  's',
#  ...]

# %%
# 7. remove words with less than 6 characters
long_words = [word for word in words if len (word) >= 6]
long_words
# Out:
# ['Berlin',
#  'Wikipedia',
#  'document',
#  'documentElement',
#  'className',
#  'client',
#  'RLCONF',
#  'wgBreakFrames',
#  'wgSeparatorTransformTable',
#  'wgDigitTransformTable',
#  'wgDefaultDateFormat',
#  'wgMonthNames',
#  'January',
#  'February',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December',
#  'wgRequestId',
#  'YCqfhfV',
#  'XDMdOp',
#  'xQAAAM',
#  'wgCSPNonce',
#  'wgCanonicalNamespace',
#  'wgCanonicalSpecialPageName',
#  'wgNamespaceNumber',
#  'wgPageName',
#  'Berlin',
#  'wgTitle',
#  'Berlin',
#  'wgCurRevisionId',
#  'wgRevisionId',
#  'wgArticleId',
#  'wgIsArticle',
#  'wgIsRedirect',
#  'wgAction',
#  'wgUserName',
#  'wgUserGroups',
#  'wgCategories',
#  'German',
#  'language',
#  'sources',
#  'articles',
#  'external',
#  'Articles',
#  'external',
#  'Articles',
#  'permanently',
#  'external',
#  'Articles',
#  'external',
#  'November',
#  'multiple',
#  'authors',
#  'Articles',
#  'external',
#  'Webarchive',
#  'template',
#  'wayback',
#  'French',
#  'language',
#  'sources',
#  'Articles',
#  'description',
#  'description',
#  'different',
#  'Wikidata',
#  'American',
#  'English',
#  'October',
#  'Wikipedia',
#  'articles',
#  'written',
#  'American',
#  'English',
#  'September',
#  'Coordinates',
#  'Wikidata',
#  'Articles',
#  'hAudio',
#  'microformats',
#  'articles',
#  'unsourced',
#  'statements',
#  'Articles',
#  'unsourced',
#  'statements',
#  'Articles',
#  'containing',
#  'potentially',
#  'statements',
#  'articles',
#  'containing',
#  'potentially',
#  'statements',
#  'Articles',
#  'unsourced',
#  'statements',
#  'multiple',
#  'manual',
#  'scaled',
#  'images',
#  'Articles',
#  'unsourced',
#  'statements',
#  'Articles',
#  'containing',
#  'German',
#  'language',
#  'Articles',
#  'unsourced',
#  'statements',
#  'January',
#  'Articles',
#  'containing',
#  'potentially',
#  'statements',
#  'Wikipedia',
#  'articles',
#  'updating',
#  'January',
#  'Wikipedia',
#  'articles',
#  'updating',
#  'Articles',
#  'containing',
#  'potentially',
#  'statements',
#  'Articles',
#  'containing',
#  'potentially',
#  'statements',
#  'Sister',
#  'project',
#  'hidden',
#  'wikidata',
#  'Sister',
#  'project',
#  'default',
#  'search',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'MusicBrainz',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'SELIBR',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'WORLDCATID',
#  'identifiers',
#  'Wikipedia',
#  'articles',
#  'multiple',
#  'identifiers',
#  'Kartographer',
#  'extension',
#  'Berlin',
#  'German',
#  'capitals',
#  'Capitals',
#  'Europe',
#  'states',
#  'Members',
#  'Hanseatic',
#  'League',
#  'Populated',
#  'places',
#  'established',
#  'century',
#  'Turkish',
#  'communities',
#  'outside',
#  'Turkey',
#  'establishments',
#  'Empire',
#  'establishments',
#  'Europe',
#  'University',
#  'Germany',
#  'wgPageContentLanguage',
#  'wgPageContentModel',
#  'wikitext',
#  'wgRelevantPageName',
#  'Berlin',
#  'wgRelevantArticleId',
#  'wgIsProbablyEditable',
#  'wgRelevantPageIsProbablyEditable',
#  'wgRestrictionEdit',
#  'wgRestrictionMove',
#  'wgMediaViewerOnClick',
#  'wgMediaViewerEnabledByDefault',
#  'wgPopupsReferencePreviews',
#  'wgPopupsConflictsWithNavPopupGadget',
#  'wgPopupsConflictsWithRefTooltipsGadget',
#  'wgVisualEditor',
#  'pageLanguageCode',
#  'pageLanguageDir',
#  'pageVariantFallbacks',
#  'wgMFDisplayWikibaseDescriptions',
#  'search',
#  'nearby',
#  'watchlist',
#  'tagline',
#  'wgWMESchemaEditAttemptStepOversample',
#  'wgULSCurrentAutonym',
#  'English',
#  'wgNoticeProject',
#  'wikipedia',
#  'wgKartographerLiveData',
#  'ExternalData',
#  'service',
#  'geoshape',
#  'wikimedia',
#  'geoshape',
#  'getgeojson',
#  'properties',
#  'Berlin',
#  'opacity',
#  'stroke',
#  'stroke',
#  'ffffff',
#  'wgCoordinates',
#  'wgCentralAuthMobileDomain',
#  'wgEditSubmitButtonLabelPublish',
#  'wgULSPosition',
#  'interlanguage',
#  'wgWikibaseItemId',
#  'RLSTATE',
#  'globalCssJs',
#  'styles',
#  'styles',
#  'noscript',
#  'styles',
#  'globalCssJs',
#  'options',
#  'loading',
#  'kartographer',
#  'styles',
#  'mediawiki',
#  'gallery',
#  'styles',
#  'vector',
#  'styles',
#  'legacy',
#  'jquery',
#  'makeCollapsible',
#  'styles',
#  'visualEditor',
#  'desktopArticleTarget',
#  'noscript',
#  'interlanguage',
#  'wikimediaBadges',
#  'wikibase',
#  'client',
#  'RLPAGEMODULES',
#  'kartographer',
#  'staticframe',
#  'enhancements',
#  'mediawiki',
#  'gallery',
#  'mediawiki',
#  'jquery',
#  'makeCollapsible',
#  'mediawiki',
#  'vector',
#  'legacy',
#  'gadget',
#  'ReferenceTooltips',
#  'gadget',
#  'charinsert',
#  'gadget',
#  'toolbar',
#  'buttons',
#  'gadget',
#  'refToolbar',
#  'gadget',
#  'switcher',
#  'centralauth',
#  'centralautologin',
#  'bootstrap',
#  'autostart',
#  'popups',
#  'visualEditor',
#  'desktopArticleTarget',
#  'visualEditor',
#  'targetLoader',
#  'eventLogging',
#  'wikimediaEvents',
#  'navigationTiming',
#  'compactlinks',
#  'interface',
#  'eventlogging',
#  'campaigns',
#  'centralNotice',
#  'centralNotice',
#  'startUp',
#  'window',
#  'function',
#  'loader',
#  'implement',
#  'options',
#  'function',
#  'jQuery',
#  'require',
#  'module',
#  'tokens',
#  'patrolToken',
#  'watchToken',
#  'csrfToken',
#  'Berlin',
#  'Wikipedia',
#  'encyclopedia',
#  'navigation',
#  'search',
#  'Capital',
#  'largest',
#  'Germany',
#  'article',
#  'German',
#  'Berlin',
#  'disambiguation',
#  'Capital',
#  'GermanyBerlinCapital',
#  'Nicholas',
#  'Quarter',
#  'Rathaus',
#  'Television',
#  'Brandenburg',
#  'Berlin',
#  'Cathedral',
#  'Charlottenburg',
#  'Palace',
#  'Berlin',
#  'Victory',
#  'Column',
#  'Gendarmenmarkt',
#  'FlagCoat',
#  'parser',
#  'output',
#  'locmap',
#  'position',
#  'absolute',
#  'parser',
#  'output',
#  'locmap',
#  'position',
#  'absolute',
#  'height',
#  'parser',
#  'output',
#  'locmap',
#  'position',
#  'absolute',
#  'parser',
#  'output',
#  'locmap',
#  'height',
#  'position',
#  'absolute',
#  'center',
#  'parser',
#  'output',
#  'locmap',
#  'height',
#  'position',
#  'absolute',
#  'parser',
#  'output',
#  'locmap',
#  'height',
#  'position',
#  'absolute',
#  'parser',
#  'output',
#  'locmap',
#  'display',
#  'inline',
#  'padding',
#  'parser',
#  'output',
#  'locmap',
#  'display',
#  'inline',
#  'padding',
#  'parser',
#  'output',
#  'locmap',
#  'display',
#  'inline',
#  'padding',
#  'BerlinLocation',
#  'within',
#  'GermanyShow',
#  'GermanyBerlinBerlin',
#  'Europe',
#  'EuropeCoordinates',
#  'parser',
#  'output',
#  'default',
#  'parser',
#  'output',
#  'parser',
#  'output',
#  'display',
#  'inline',
#  'parser',
#  'output',
#  'nondefault',
#  'parser',
#  'output',
#  'display',
#  'parser',
#  'output',
#  'longitude',
#  'parser',
#  'output',
#  'latitude',
#  'nowrap',
#  'Coordinates',
#  'Country',
#  'GermanyStateBerlinGovernment',
#  'BodyAbgeordnetenhaus',
#  'Berlin',
#  'Governing',
#  'MayorMichael',
#  'Elevation',
#  'Population',
#  'December',
#  'DemonymsBerliner',
#  'English',
#  'Berliner',
#  'Berlinerin',
#  'German',
#  'zoneUTC',
#  'Summer',
#  'GeocodeNUTS',
#  'Region',
#  'codeDE',
#  'BEVehicle',
#  'registrationB',
#  'nominal',
#  'billion',
#  'capita',
#  'GeoTLD',
#  'berlinHDI',
#  'Websitewww',
#  'berlin',
#  'Berlin',
#  'German',
#  'listen',
#  'capital',
#  'largest',
#  'Germany',
#  'population',
#  'inhabitants',
#  'December',
#  'populous',
#  'European',
#  'according',
#  'population',
#  'within',
#  'limits',
#  'Germany',
#  'constituent',
#  'states',
#  'Berlin',
#  'surrounded',
#  'Brandenburg',
#  'contiguous',
#  'Potsdam',
#  'Brandenburg',
#  'capital',
#  'Berlin',
#  'population',
#  'around',
#  'million',
#  'second',
#  'populous',
#  'Germany',
#  'Berlin',
#  'Brandenburg',
#  'capital',
#  'region',
#  'million',
#  'inhabitants',
#  'Germany',
#  'largest',
#  'metropolitan',
#  'region',
#  'regions',
#  'Berlin',
#  'straddles',
#  'tributary',
#  'western',
#  'borough',
#  'Spandau',
#  'topographical',
#  'features',
#  'western',
#  'southeastern',
#  'boroughs',
#  'formed',
#  'rivers',
#  'largest',
#  'ggelsee',
#  'location',
#  'European',
#  'Berlin',
#  'influenced',
#  'temperate',
#  'seasonal',
#  'climate',
#  'composed',
#  'forests',
#  'gardens',
#  'rivers',
#  'canals',
#  'Central',
#  'German',
#  'dialect',
#  'Berlin',
#  'dialect',
#  'variant',
#  'Lusatian',
#  'Marchian',
#  'dialects',
#  'documented',
#  'century',
#  'crossing',
#  'important',
#  'historic',
#  'routes',
#  'Berlin',
#  'became',
#  'capital',
#  'Margraviate',
#  'Brandenburg',
#  'Kingdom',
#  'Prussia',
#  'German',
#  'Empire',
#  'Weimar',
#  'Republic',
#  'Berlin',
#  'largest',
#  'municipality',
#  'subsequent',
#  'occupation',
#  'victorious',
#  'countries',
#  'divided',
#  'Berlin',
#  'became',
#  'German',
#  'exclave',
#  'surrounded',
#  'Berlin',
#  'German',
#  'territory',
#  'Berlin',
#  'declared',
#  'capital',
#  'Germany',
#  'became',
#  'German',
#  'capital',
#  'Following',
#  'German',
#  'reunification',
#  'Berlin',
#  'became',
#  'capital',
#  'Germany',
#  'Berlin',
#  'culture',
#  'politics',
#  'science',
#  'economy',
#  'service',
#  'sector',
#  'encompassing',
#  'diverse',
#  'creative',
#  'industries',
#  'research',
#  'facilities',
#  'corporations',
#  'convention',
#  'venues',
#  'Berlin',
#  'serves',
#  'continental',
#  'traffic',
#  'highly',
#  'complex',
#  'public',
#  'transportation',
#  'network',
#  'metropolis',
#  'popular',
#  'tourist',
#  'destination',
#  'Significant',
#  'industries',
#  'include',
#  'pharmaceuticals',
#  'biomedical',
#  'engineering',
#  'biotechnology',
#  'construction',
#  'electronics',
#  'Berlin',
#  'renowned',
#  'universities',
#  'Humboldt',
#  'Universit',
#  'Berlin',
#  'Berlin',
#  'Technische',
#  'Universit',
#  'Berlin',
#  'Berlin',
#  'Universit',
#  'Berlin',
#  'University',
#  'Berlin',
#  'Universit',
#  'University',
#  'Berlin',
#  'Zoological',
#  'Garden',
#  'visited',
#  'Europe',
#  'popular',
#  'worldwide',
#  'oldest',
#  'studio',
#  'complex',
#  'Berlin',
#  'increasingly',
#  'popular',
#  'location',
#  'international',
#  'productions',
#  'festivals',
#  'diverse',
#  'architecture',
#  'nightlife',
#  'contemporary',
#  'quality',
#  'living',
#  'Berlin',
#  'emergence',
#  'cosmopolitan',
#  'entrepreneurial',
#  'Berlin',
#  'contains',
#  'Heritage',
#  'Museum',
#  'Island',
#  'Palaces',
#  'Potsdam',
#  'Berlin',
#  'Berlin',
#  'Modernism',
#  'Housing',
#  'Estates',
#  'landmarks',
#  'include',
#  'Brandenburg',
#  'Reichstag',
#  'building',
#  'Potsdamer',
#  'Memorial',
#  'Murdered',
#  'Europe',
#  'Berlin',
#  'Memorial',
#  'Gallery',
#  'Berlin',
#  'Victory',
#  'Column',
#  'Berlin',
#  'Cathedral',
#  'Berlin',
#  'Television',
#  'tallest',
#  'structure',
#  'Germany',
#  'Berlin',
#  'numerous',
#  'museums',
#  'galleries',
#  'libraries',
#  'orchestras',
#  'sporting',
#  'events',
#  'include',
#  'National',
#  'Gallery',
#  'Museum',
#  'Pergamon',
#  'Museum',
#  'German',
#  'Historical',
#  'Museum',
#  'Jewish',
#  'Museum',
#  'Berlin',
#  'Natural',
#  'History',
#  'Museum',
#  'Humboldt',
#  'Berlin',
#  'Library',
#  'Berlin',
#  'Berlin',
#  'Philharmonic',
#  'Berlin',
#  'Marathon',
#  'Contents',
#  'History',
#  'Etymology',
#  'centuries',
#  'centuries',
#  'centuries',
#  'Geography',
#  'Topography',
#  'Climate',
#  'Cityscape',
#  'Architecture',
#  'Demographics',
#  'Nationalities',
#  'Languages',
#  'Religion',
#  'Government',
#  'Boroughs',
#  'sister',
#  'cities',
#  'Capital',
#  'Economy',
#  'Companies',
#  'Tourism',
#  'conventions',
#  'Creative',
#  'industries',
#  'Quality',
#  'Infrastructure',
#  'Transport',
#  'Intercity',
#  'Public',
#  'transport',
#  'Airports',
#  'Cycling',
#  'Rohrpost',
#  'pneumatic',
#  'postal',
#  'network',
#  'Energy',
#  'Health',
#  'Telecommunication',
#  'Education',
#  'Higher',
#  'education',
#  'Research',
#  'Culture',
#  'Galleries',
#  'museums',
#  'Nightlife',
#  'festivals',
#  'Performing',
#  'Cuisine',
#  'Recreation',
#  'References',
#  'Citations',
#  'Sources',
#  'External',
#  'History',
#  'article',
#  'History',
#  'Berlin',
#  'Further',
#  'information',
#  'Timeline',
#  'Berlin',
#  'Etymology',
#  'Berlin',
#  'northeastern',
#  'Germany',
#  'constituted',
#  'together',
#  'Thuringian',
#  'confluence',
#  'onwards',
#  'eastern',
#  'border',
#  'Frankish',
#  'Frankish',
#  'primarily',
#  'inhabited',
#  'Germanic',
#  'tribes',
#  'Franks',
#  'Saxons',
#  'regions',
#  'border',
#  'rivers',
#  'inhabited',
#  'Slavic',
#  'tribes',
#  'cities',
#  'villages',
#  'northeastern',
#  'Germany',
#  'Slavic',
#  'derived',
#  'Germania',
#  'Slavica',
#  'Typical',
#  'Germanized',
#  'suffixes',
#  'Slavic',
#  'origin',
#  'itzsch',
#  'prefixes',
#  'Windisch',
#  'Wendisch',
#  'Berlin',
#  'language',
#  'Slavic',
#  'inhabitants',
#  'Berlin',
#  'related',
#  'Polabian',
#  'beginning',
#  'sounds',
#  'German',
#  'appears',
#  'therefore',
#  'canting',
#  'Berlin',
#  'twelve',
#  'boroughs',
#  'partly',
#  'Slavic',
#  'derived',
#  'Pankow',
#  'populous',
#  'Steglitz',
#  'Zehlendorf',
#  'Marzahn',
#  'Hellersdorf',
#  'Treptow',
#  'penick',
#  'Spandau',
#  'Spandow',
#  'ninety',
#  'neighborhoods',
#  'twenty',
#  'partly',
#  'Slavic',
#  'derived',
#  'Altglienicke',
#  'Treptow',
#  'Buckow',
#  'Kladow',
#  'penick',
#  'Lankwitz',
#  'Malchow',
#  'Marzahn',
#  'Pankow',
#  'Prenzlauer',
#  'ckwitz',
#  'Spandau',
#  'Stadtrandsiedlung',
#  'Malchow',
#  'Steglitz',
#  'Zehlendorf',
#  'neighborhood',
#  'Moabit',
#  'French',
#  'derived',
#  'Buchholz',
#  'Huguenots',
#  'centuries',
#  'Berlin',
#  'Berlin',
#  'Cathedral',
#  'Berlin',
#  'Palace',
#  'earliest',
#  'evidence',
#  'settlements',
#  'Berlin',
#  'remnants',
#  'foundation',
#  'excavations',
#  'Berlin',
#  'wooden',
#  'approximately',
#  'written',
#  'records',
#  'present',
#  'Berlin',
#  'century',
#  'Spandau',
#  'mentioned',
#  'penick',
#  'although',
#  'Berlin',
#  'central',
#  'Berlin',
#  'traced',
#  'Fischerinsel',
#  'mentioned',
#  'document',
#  'Berlin',
#  'across',
#  'called',
#  'Nikolaiviertel',
#  'referenced',
#  'document',
#  'considered',
#  'founding',
#  'formed',
#  'economic',
#  'social',
#  'profited',
#  'staple',
#  'important',
#  'routes',
#  'Imperii',
#  'Bruges',
#  'Novgorod',
#  'formed',
#  'alliance',
#  'common',
#  'external',
#  'policy',
#  'internal',
#  'administrations',
#  'separated',
#  'Frederick',
#  'became',
#  'elector',
#  'Margraviate',
#  'Brandenburg',
#  'During',
#  'century',
#  'successors',
#  'established',
#  'Berlin',
#  'capital',
#  'margraviate',
#  'subsequent',
#  'members',
#  'Hohenzollern',
#  'family',
#  'Berlin',
#  'electors',
#  'Brandenburg',
#  'Prussia',
#  'eventually',
#  'German',
#  ...]

# %%
# 8. create a Counter object from the long words
c = Counter(long_words)
c
# Out:
# Counter({'Berlin': 670,
#          'Wikipedia': 27,
#          'document': 3,
#          'documentElement': 1,
#          'className': 1,
#          'client': 2,
#          'RLCONF': 1,
#          'wgBreakFrames': 1,
#          'wgSeparatorTransformTable': 1,
#          'wgDigitTransformTable': 1,
#          'wgDefaultDateFormat': 1,
#          'wgMonthNames': 1,
#          'January': 31,
#          'February': 46,
#          'August': 65,
#          'September': 33,
#          'October': 38,
#          'November': 45,
#          'December': 35,
#          'wgRequestId': 1,
#          'YCqfhfV': 1,
#          'XDMdOp': 1,
#          'xQAAAM': 1,
#          'wgCSPNonce': 1,
#          'wgCanonicalNamespace': 1,
#          'wgCanonicalSpecialPageName': 1,
#          'wgNamespaceNumber': 1,
#          'wgPageName': 1,
#          'wgTitle': 1,
#          'wgCurRevisionId': 1,
#          'wgRevisionId': 1,
#          'wgArticleId': 1,
#          'wgIsArticle': 1,
#          'wgIsRedirect': 1,
#          'wgAction': 1,
#          'wgUserName': 1,
#          'wgUserGroups': 1,
#          'wgCategories': 1,
#          'German': 132,
#          'language': 16,
#          'sources': 4,
#          'articles': 45,
#          'external': 11,
#          'Articles': 21,
#          'permanently': 2,
#          'multiple': 7,
#          'authors': 3,
#          'Webarchive': 2,
#          'template': 3,
#          'wayback': 2,
#          'French': 14,
#          'description': 3,
#          'different': 11,
#          'Wikidata': 2,
#          'American': 11,
#          'English': 11,
#          'written': 3,
#          'Coordinates': 3,
#          'hAudio': 2,
#          'microformats': 1,
#          'unsourced': 10,
#          'statements': 18,
#          'containing': 12,
#          'potentially': 10,
#          'manual': 2,
#          'scaled': 2,
#          'images': 2,
#          'updating': 3,
#          'Sister': 4,
#          'project': 5,
#          'hidden': 3,
#          'wikidata': 3,
#          'default': 3,
#          'search': 3,
#          'identifiers': 15,
#          'MusicBrainz': 2,
#          'SELIBR': 3,
#          'WORLDCATID': 2,
#          'Kartographer': 2,
#          'extension': 2,
#          'capitals': 2,
#          'Capitals': 5,
#          'Europe': 32,
#          'states': 18,
#          'Members': 1,
#          'Hanseatic': 4,
#          'League': 4,
#          'Populated': 1,
#          'places': 5,
#          'established': 8,
#          'century': 17,
#          'Turkish': 8,
#          'communities': 7,
#          'outside': 5,
#          'Turkey': 6,
#          'establishments': 4,
#          'Empire': 7,
#          'University': 17,
#          'Germany': 99,
#          'wgPageContentLanguage': 1,
#          'wgPageContentModel': 1,
#          'wikitext': 1,
#          'wgRelevantPageName': 1,
#          'wgRelevantArticleId': 1,
#          'wgIsProbablyEditable': 1,
#          'wgRelevantPageIsProbablyEditable': 1,
#          'wgRestrictionEdit': 1,
#          'wgRestrictionMove': 1,
#          'wgMediaViewerOnClick': 1,
#          'wgMediaViewerEnabledByDefault': 1,
#          'wgPopupsReferencePreviews': 1,
#          'wgPopupsConflictsWithNavPopupGadget': 1,
#          'wgPopupsConflictsWithRefTooltipsGadget': 1,
#          'wgVisualEditor': 1,
#          'pageLanguageCode': 1,
#          'pageLanguageDir': 1,
#          'pageVariantFallbacks': 1,
#          'wgMFDisplayWikibaseDescriptions': 1,
#          'nearby': 4,
#          'watchlist': 1,
#          'tagline': 1,
#          'wgWMESchemaEditAttemptStepOversample': 1,
#          'wgULSCurrentAutonym': 1,
#          'wgNoticeProject': 1,
#          'wikipedia': 8,
#          'wgKartographerLiveData': 1,
#          'ExternalData': 1,
#          'service': 12,
#          'geoshape': 2,
#          'wikimedia': 7,
#          'getgeojson': 1,
#          'properties': 1,
#          'opacity': 1,
#          'stroke': 2,
#          'ffffff': 1,
#          'wgCoordinates': 1,
#          'wgCentralAuthMobileDomain': 1,
#          'wgEditSubmitButtonLabelPublish': 1,
#          'wgULSPosition': 1,
#          'interlanguage': 2,
#          'wgWikibaseItemId': 1,
#          'RLSTATE': 1,
#          'globalCssJs': 2,
#          'styles': 8,
#          'noscript': 2,
#          'options': 2,
#          'loading': 1,
#          'kartographer': 2,
#          'mediawiki': 4,
#          'gallery': 2,
#          'vector': 23,
#          'legacy': 2,
#          'jquery': 2,
#          'makeCollapsible': 2,
#          'visualEditor': 3,
#          'desktopArticleTarget': 2,
#          'wikimediaBadges': 1,
#          'wikibase': 4,
#          'RLPAGEMODULES': 1,
#          'staticframe': 1,
#          'enhancements': 1,
#          'gadget': 5,
#          'ReferenceTooltips': 1,
#          'charinsert': 1,
#          'toolbar': 1,
#          'buttons': 1,
#          'refToolbar': 1,
#          'switcher': 1,
#          'centralauth': 1,
#          'centralautologin': 1,
#          'bootstrap': 1,
#          'autostart': 1,
#          'popups': 1,
#          'targetLoader': 1,
#          'eventLogging': 1,
#          'wikimediaEvents': 1,
#          'navigationTiming': 1,
#          'compactlinks': 1,
#          'interface': 1,
#          'eventlogging': 1,
#          'campaigns': 1,
#          'centralNotice': 2,
#          'startUp': 1,
#          'window': 3,
#          'function': 6,
#          'loader': 1,
#          'implement': 1,
#          'jQuery': 1,
#          'require': 1,
#          'module': 1,
#          'tokens': 1,
#          'patrolToken': 1,
#          'watchToken': 1,
#          'csrfToken': 1,
#          'encyclopedia': 1,
#          'navigation': 15,
#          'Capital': 11,
#          'largest': 45,
#          'article': 20,
#          'disambiguation': 1,
#          'GermanyBerlinCapital': 1,
#          'Nicholas': 2,
#          'Quarter': 2,
#          'Rathaus': 6,
#          'Television': 2,
#          'Brandenburg': 53,
#          'Cathedral': 12,
#          'Charlottenburg': 11,
#          'Palace': 11,
#          'Victory': 4,
#          'Column': 4,
#          'Gendarmenmarkt': 4,
#          'FlagCoat': 1,
#          'parser': 100,
#          'output': 98,
#          'locmap': 9,
#          'position': 9,
#          'absolute': 6,
#          'height': 6,
#          'center': 35,
#          'display': 17,
#          'inline': 6,
#          'padding': 12,
#          'BerlinLocation': 1,
#          'within': 6,
#          'GermanyShow': 1,
#          'GermanyBerlinBerlin': 1,
#          'EuropeCoordinates': 1,
#          'nondefault': 1,
#          'longitude': 1,
#          'latitude': 1,
#          'nowrap': 2,
#          'Country': 4,
#          'GermanyStateBerlinGovernment': 1,
#          'BodyAbgeordnetenhaus': 1,
#          'Governing': 8,
#          'MayorMichael': 1,
#          'Elevation': 1,
#          'Population': 3,
#          'DemonymsBerliner': 1,
#          'Berliner': 36,
#          'Berlinerin': 1,
#          'zoneUTC': 1,
#          'Summer': 7,
#          'GeocodeNUTS': 1,
#          'Region': 2,
#          'codeDE': 1,
#          'BEVehicle': 1,
#          'registrationB': 1,
#          'nominal': 1,
#          'billion': 7,
#          'capita': 2,
#          'GeoTLD': 1,
#          'berlinHDI': 1,
#          'Websitewww': 1,
#          'berlin': 17,
#          'listen': 1,
#          'capital': 34,
#          'population': 22,
#          'inhabitants': 8,
#          'populous': 4,
#          'European': 35,
#          'according': 3,
#          'limits': 2,
#          'constituent': 2,
#          'surrounded': 3,
#          'contiguous': 1,
#          'Potsdam': 15,
#          'around': 24,
#          'million': 19,
#          'second': 3,
#          'region': 9,
#          'metropolitan': 3,
#          'regions': 8,
#          'straddles': 1,
#          'tributary': 1,
#          'western': 9,
#          'borough': 12,
#          'Spandau': 11,
#          'topographical': 1,
#          'features': 8,
#          'southeastern': 1,
#          'boroughs': 13,
#          'formed': 8,
#          'rivers': 4,
#          'ggelsee': 2,
#          'location': 5,
#          'influenced': 2,
#          'temperate': 2,
#          'seasonal': 1,
#          'climate': 8,
#          'composed': 1,
#          'forests': 1,
#          'gardens': 3,
#          'canals': 1,
#          'Central': 3,
#          'dialect': 5,
#          'variant': 4,
#          'Lusatian': 1,
#          'Marchian': 1,
#          'dialects': 2,
#          'documented': 1,
#          'crossing': 4,
#          'important': 13,
#          'historic': 4,
#          'routes': 4,
#          'became': 24,
#          'Margraviate': 3,
#          'Kingdom': 10,
#          'Prussia': 7,
#          'Weimar': 5,
#          'Republic': 15,
#          'municipality': 1,
#          'subsequent': 2,
#          'occupation': 3,
#          'victorious': 2,
#          'countries': 8,
#          'divided': 6,
#          'exclave': 1,
#          'territory': 4,
#          'declared': 1,
#          'Following': 4,
#          'reunification': 5,
#          'culture': 10,
#          'politics': 2,
#          'science': 3,
#          'economy': 4,
#          'sector': 4,
#          'encompassing': 1,
#          'diverse': 7,
#          'creative': 4,
#          'industries': 8,
#          'research': 11,
#          'facilities': 1,
#          'corporations': 3,
#          'convention': 2,
#          'venues': 3,
#          'serves': 2,
#          'continental': 4,
#          'traffic': 4,
#          'highly': 4,
#          'complex': 4,
#          'public': 15,
#          'transportation': 3,
#          'network': 5,
#          'metropolis': 3,
#          'popular': 12,
#          'tourist': 1,
#          'destination': 3,
#          'Significant': 1,
#          'include': 10,
#          'pharmaceuticals': 1,
#          'biomedical': 1,
#          'engineering': 2,
#          'biotechnology': 2,
#          'construction': 9,
#          'electronics': 3,
#          'renowned': 6,
#          'universities': 5,
#          'Humboldt': 10,
#          'Universit': 12,
#          'Technische': 3,
#          'Zoological': 1,
#          'Garden': 2,
#          'visited': 5,
#          'worldwide': 1,
#          'oldest': 4,
#          'studio': 3,
#          'increasingly': 1,
#          'international': 22,
#          'productions': 2,
#          'festivals': 6,
#          'architecture': 8,
#          'nightlife': 3,
#          'contemporary': 4,
#          'quality': 1,
#          'living': 2,
#          'emergence': 1,
#          'cosmopolitan': 2,
#          'entrepreneurial': 2,
#          'contains': 2,
#          'Heritage': 7,
#          'Museum': 31,
#          'Island': 7,
#          'Palaces': 4,
#          'Modernism': 1,
#          'Housing': 2,
#          'Estates': 1,
#          'landmarks': 2,
#          'Reichstag': 6,
#          'building': 10,
#          'Potsdamer': 10,
#          'Memorial': 9,
#          'Murdered': 2,
#          'Gallery': 9,
#          'tallest': 5,
#          'structure': 1,
#          'numerous': 6,
#          'museums': 9,
#          'galleries': 6,
#          'libraries': 3,
#          'orchestras': 4,
#          'sporting': 2,
#          'events': 7,
#          'National': 5,
#          'Pergamon': 3,
#          'Historical': 2,
#          'Jewish': 12,
#          'Natural': 2,
#          'History': 13,
#          'Library': 1,
#          'Philharmonic': 4,
#          'Marathon': 4,
#          'Contents': 1,
#          'Etymology': 2,
#          'centuries': 7,
#          'Geography': 7,
#          'Topography': 2,
#          'Climate': 9,
#          'Cityscape': 2,
#          'Architecture': 5,
#          'Demographics': 4,
#          'Nationalities': 2,
#          'Languages': 4,
#          'Religion': 5,
#          'Government': 4,
#          'Boroughs': 4,
#          'sister': 5,
#          'cities': 26,
#          'Economy': 4,
#          'Companies': 3,
#          'Tourism': 3,
#          'conventions': 3,
#          'Creative': 7,
#          'Quality': 5,
#          'Infrastructure': 3,
#          'Transport': 5,
#          'Intercity': 3,
#          'Public': 3,
#          'transport': 10,
#          'Airports': 3,
#          'Cycling': 3,
#          'Rohrpost': 3,
#          'pneumatic': 3,
#          'postal': 3,
#          'Energy': 3,
#          'Health': 4,
#          'Telecommunication': 2,
#          'Education': 5,
#          'Higher': 2,
#          'education': 5,
#          'Research': 6,
#          'Culture': 14,
#          'Galleries': 2,
#          'Nightlife': 3,
#          'Performing': 2,
#          'Cuisine': 2,
#          'Recreation': 2,
#          'References': 2,
#          'Citations': 2,
#          'Sources': 2,
#          'External': 2,
#          'Further': 3,
#          'information': 6,
#          'Timeline': 1,
#          'northeastern': 3,
#          'constituted': 1,
#          'together': 3,
#          'Thuringian': 1,
#          'confluence': 1,
#          'onwards': 1,
#          'eastern': 6,
#          'border': 12,
#          'Frankish': 2,
#          'primarily': 1,
#          'inhabited': 2,
#          'Germanic': 3,
#          'tribes': 2,
#          'Franks': 1,
#          'Saxons': 1,
#          'Slavic': 6,
#          'villages': 2,
#          'derived': 4,
#          'Germania': 3,
#          'Slavica': 1,
#          'Typical': 3,
#          'Germanized': 1,
#          'suffixes': 1,
#          'origin': 2,
#          'itzsch': 1,
#          'prefixes': 2,
#          'Windisch': 1,
#          'Wendisch': 1,
#          'related': 4,
#          'Polabian': 1,
#          'beginning': 2,
#          'sounds': 1,
#          'appears': 1,
#          'therefore': 1,
#          'canting': 1,
#          'twelve': 2,
#          'partly': 5,
#          'Pankow': 8,
#          'Steglitz': 5,
#          'Zehlendorf': 6,
#          'Marzahn': 5,
#          'Hellersdorf': 3,
#          'Treptow': 5,
#          'penick': 6,
#          'Spandow': 1,
#          'ninety': 1,
#          'neighborhoods': 7,
#          'twenty': 1,
#          'Altglienicke': 2,
#          'Buckow': 2,
#          'Kladow': 2,
#          'Lankwitz': 2,
#          'Malchow': 4,
#          'Prenzlauer': 3,
#          'ckwitz': 2,
#          'Stadtrandsiedlung': 2,
#          'neighborhood': 1,
#          'Moabit': 4,
#          'Buchholz': 2,
#          'Huguenots': 2,
#          'earliest': 1,
#          'evidence': 2,
#          'settlements': 1,
#          'remnants': 1,
#          'foundation': 2,
#          'excavations': 1,
#          'wooden': 2,
#          'approximately': 9,
#          'records': 2,
#          'present': 7,
#          'mentioned': 2,
#          'although': 2,
#          'central': 9,
#          'traced': 1,
#          'Fischerinsel': 1,
#          'across': 2,
#          'called': 2,
#          'Nikolaiviertel': 1,
#          'referenced': 1,
#          'considered': 2,
#          'founding': 3,
#          'economic': 7,
#          'social': 2,
#          'profited': 1,
#          'staple': 1,
#          'Imperii': 1,
#          'Bruges': 4,
#          'Novgorod': 2,
#          'alliance': 1,
#          'common': 4,
#          'policy': 3,
#          'internal': 1,
#          'administrations': 1,
#          'separated': 4,
#          'Frederick': 10,
#          'elector': 2,
#          'During': 4,
#          'successors': 1,
#          'margraviate': 1,
#          'members': 9,
#          'Hohenzollern': 4,
#          'family': 3,
#          'electors': 4,
#          'eventually': 2,
#          'emperors': 1,
#          'Irontooth': 1,
#          'started': 2,
#          'palace': 6,
#          'protests': 1,
#          'citizens': 3,
#          'against': 2,
#          'culminated': 1,
#          'Indignation': 1,
#          'Unwille': 1,
#          'protest': 1,
#          'successful': 3,
#          'citizenry': 1,
#          'political': 5,
#          'privileges': 1,
#          'finished': 2,
#          'gradually': 1,
#          'Albrecht': 1,
#          'Achilles': 1,
#          'residence': 6,
#          'Officially': 1,
#          'permanent': 2,
#          'Hohenzollerns': 1,
#          'Cicero': 1,
#          'however': 3,
#          'status': 3,
#          'officially': 2,
#          'Lutheran': 3,
#          'Thirty': 1,
#          'between': 15,
#          'devastated': 2,
#          'houses': 8,
#          'damaged': 1,
#          'destroyed': 4,
#          'William': 4,
#          'Elector': 2,
#          'succeeded': 1,
#          'father': 1,
#          'George': 1,
#          'initiated': 3,
#          'promoting': 2,
#          'immigration': 6,
#          'religious': 8,
#          'tolerance': 1,
#          'offered': 1,
#          'asylum': 2,
#          'percent': 8,
#          'residents': 14,
#          'because': 3,
#          'Huguenot': 3,
#          'immigrants': 3,
#          'Bohemia': 1,
#          'Poland': 5,
#          'Salzburg': 3,
#          'expanded': 4,
#          'rapidly': 1,
#          'following': 3,
#          'personal': 4,
#          'crowned': 1,
#          'himself': 1,
#          'replacing': 3,
#          'nigsberg': 2,
#          'attempt': 2,
#          'centralise': 1,
#          'merged': 2,
#          'Friedrichswerder': 1,
#          'Friedrichstadt': 2,
#          'Dorotheenstadt': 1,
#          'Residenzstadt': 1,
#          'Enlightenment': 1,
#          'briefly': 1,
#          'occupied': 3,
#          'during': 14,
#          'Russian': 6,
#          'France': 11,
#          'victory': 1,
#          'Fourth': 1,
#          'Coalition': 1,
#          'Napoleon': 1,
#          'Bonaparte': 1,
#          'marched': 2,
#          'granted': 2,
#          'government': 13,
#          'Province': 1,
#          'Industrial': 1,
#          'Revolution': 1,
#          'transformed': 1,
#          'dramatically': 1,
#          'railway': 4,
#          'Additional': 1,
#          'suburbs': 4,
#          'developed': 7,
#          'increased': 5,
#          'neighboring': 2,
#          'including': 14,
#          'Wedding': 2,
#          'several': 16,
#          'others': 6,
#          'incorporated': 4,
#          'founded': 11,
#          'district': 3,
#          'separate': 2,
#          'become': 10,
#          'fertile': 2,
#          'ground': 3,
#          'Expressionist': 1,
#          'movement': 4,
#          'fields': 1,
#          'painting': 2,
#          'cinema': 2,
#          'artistic': 1,
#          'invented': 1,
#          'republic': 2,
#          'proclaimed': 3,
#          'Philipp': 1,
#          'Scheidemann': 1,
#          'Greater': 5,
#          'dozens': 1,
#          'suburban': 2,
#          'estates': 1,
#          'almost': 3,
#          'doubled': 3,
#          'underwent': 1,
#          'unrest': 1,
#          'uncertainties': 1,
#          'Roaring': 1,
#          'Twenties': 2,
#          'experienced': 2,
#          'heyday': 1,
#          'leadership': 1,
#          'technology': 5,
#          'humanities': 1,
#          'planning': 2,
#          'higher': 4,
#          'Albert': 1,
#          'Einstein': 1,
#          'prominence': 1,
#          'awarded': 1,
#          'Physics': 1,
#          'Hitler': 1,
#          'diminished': 1,
#          'community': 5,
#          'country': 3,
#          'result': 1,
#          'emigration': 1,
#          'Kristallnacht': 1,
#          'thousands': 1,
#          'imprisoned': 1,
#          'Sachsenhausen': 1,
#          'concentration': 1,
#          'Starting': 2,
#          'shipped': 1,
#          'Auschwitz': 1,
#          'heavily': 2,
#          'bombed': 1,
#          'history': 17,
#          'citation': 12,
#          'needed': 5,
#          'Allied': 3,
#          'Battle': 1,
#          'Allies': 7,
#          'dropped': 1,
#          'destroying': 1,
#          'Around': 3,
#          'civilians': 1,
#          'killed': 1,
#          'received': 2,
#          'numbers': 3,
#          'refugees': 3,
#          'Eastern': 4,
#          'provinces': 1,
#          'powers': 2,
#          'sectors': 5,
#          'analogous': 1,
#          'Western': 13,
#          'United': 12,
#          'States': 7,
#          'Soviet': 7,
#          'painted': 2,
#          'barrier': 1,
#          'shared': 2,
#          'administrative': 3,
#          'responsibilities': 1,
#          'However': 2,
#          'extended': 2,
#          'currency': 1,
#          'reform': 2,
#          'imposed': 1,
#          'blockade': 2,
#          'access': 7,
#          'entirely': 1,
#          'inside': 6,
#          'controlled': 2,
#          'airlift': 1,
#          'conducted': 1,
#          'overcame': 1,
#          'supplying': 1,
#          'supplies': 1,
#          'Federal': 14,
#          'included': 3,
#          'British': 4,
#          'excluding': 1,
#          'Marxist': 1,
#          'Leninist': 1,
#          'Democratic': 3,
#          'remained': 1,
#          'politically': 1,
#          'aligned': 1,
#          'despite': 1,
#          'geographic': 1,
#          'isolation': 1,
#          'Airline': 1,
#          'airlines': 3,
#          'process': 1,
#          'formally': 1,
#          'tensions': 1,
#          'recognize': 1,
#          'itself': 4,
#          'escalated': 1,
#          'standoff': 1,
#          'Checkpoint': 2,
#          'Charlie': 2,
#          'unique': 1,
#          'Kennedy': 3,
#          'speech': 2,
#          'underlining': 1,
#          'support': 1,
#          'completely': 1,
#          'Although': 1,
#          'possible': 1,
#          'Westerners': 1,
#          'through': 7,
#          'strictly': 1,
#          'checkpoints': 1,
#          'Easterners': 1,
#          'travel': 1,
#          'prohibited': 1,
#          'agreement': 1,
#          'guaranteed': 2,
#          'pressure': 1,
#          'subsequently': 1,
#          'mostly': 6,
#          'demolished': 3,
#          'preserves': 1,
#          'portion': 5,
#          'reunified': 6,
#          'Walter': 3,
#          'Momper': 1,
#          'interim': 1,
#          'elections': 1,
#          'resulted': 1,
#          'elected': 4,
#          'office': 3,
#          'offices': 2,
#          'mayors': 4,
#          'expiring': 1,
#          'Eberhard': 1,
#          'Diepgen': 1,
#          'former': 16,
#          'reunited': 1,
#          'soldiers': 1,
#          'Britain': 1,
#          'parade': 2,
#          'ceremonies': 1,
#          'withdrawal': 1,
#          'allied': 1,
#          'troops': 2,
#          'allowing': 2,
#          'departed': 1,
#          'departure': 1,
#          'forces': 1,
#          'Bundestag': 4,
#          'Parliament': 4,
#          'completed': 3,
#          'tmulti': 13,
#          'thumbinner': 2,
#          'direction': 2,
#          'column': 5,
#          'sizing': 4,
#          'tsingle': 3,
#          'margin': 16,
#          'theader': 1,
#          'weight': 5,
#          'background': 12,
#          'transparent': 10,
#          'thumbcaption': 3,
#          'justify': 1,
#          'content': 4,
#          'rebuilt': 2,
#          'nearing': 1,
#          'completion': 1,
#          'reducing': 1,
#          'number': 16,
#          'terrorist': 1,
#          'attack': 2,
#          'linked': 1,
#          'deliberately': 1,
#          'driven': 1,
#          'Christmas': 2,
#          'market': 2,
#          'Kaiser': 4,
#          'Wilhelm': 3,
#          'Church': 14,
#          'leaving': 1,
#          'people': 9,
#          'injured': 1,
#          'Airport': 13,
#          'opened': 7,
#          'planned': 2,
#          'Terminal': 3,
#          'coming': 1,
#          'flights': 1,
#          'ending': 1,
#          'passenger': 1,
#          'resulting': 1,
#          'pandemic': 2,
#          'announced': 2,
#          'temporarily': 1,
#          'nefeld': 8,
#          'connecting': 3,
#          'Alexanderplatz': 6,
#          'Hauptbahnhof': 5,
#          'stations': 4,
#          'Linden': 5,
#          'Museumsinsel': 3,
#          'station': 6,
#          'expected': 1,
#          'complete': 1,
#          'partial': 1,
#          'opening': 2,
#          'museum': 5,
#          'housed': 4,
#          'reconstructed': 5,
#          'postponed': 1,
#          'Satellite': 2,
#          'marshy': 1,
#          'woodlands': 3,
#          'mainly': 3,
#          'topography': 1,
#          'Northern': 3,
#          'stretches': 3,
#          'northern': 2,
#          'Russia': 4,
#          'Urstromtal': 1,
#          'glacial': 1,
#          'valley': 2,
#          'Barnim': 2,
#          'Plateau': 3,
#          'Teltow': 2,
#          'plateau': 1,
#          'meltwater': 1,
#          'flowing': 1,
#          'sheets': 1,
#          'Weichselian': 1,
#          'glaciation': 1,
#          'follows': 1,
#          'empties': 1,
#          'course': 3,
#          'Tegeler': 1,
#          'Wannsee': 2,
#          'series': 2,
#          'Substantial': 1,
#          'extend': 1,
#          'plateaus': 1,
#          'Valley': 4,
#          'Reinickendorf': 3,
#          'Wilmersdorf': 4,
#          'Tempelhof': 7,
#          'neberg': 6,
#          'Glacial': 1,
#          'Arkenberge': 1,
#          'meters': 5,
#          'elevation': 4,
#          'highest': 4,
#          'Through': 1,
#          'disposal': 1,
#          'debris': 1,
#          'surpassed': 1,
#          'Teufelsberg': 1,
#          'rubble': 1,
#          'Second': 4,
#          'ggelberge': 1,
#          'natural': 4,
#          'lowest': 2,
#          'Spektesee': 1,
#          'outskirts': 1,
#          'covered': 1,
#          'oceanic': 2,
#          'slight': 1,
#          'influence': 2,
#          'especially': 2,
#          'isotherm': 1,
#          'changes': 2,
#          'annual': 8,
#          'rainfall': 4,
#          'masses': 1,
#          'greater': 1,
#          'abundance': 1,
#          'period': 3,
#          'moderate': 2,
#          'summer': 3,
#          'temperatures': 3,
#          'sometimes': 2,
#          'semicontinental': 1,
#          'winters': 1,
#          'rigorous': 1,
#          'transitional': 1,
#          'frosts': 1,
#          'winter': 2,
#          'larger': 1,
#          'temperature': 3,
#          'differences': 1,
#          'seasons': 1,
#          'typical': 1,
#          'climates': 1,
#          'Furthermore': 2,
#          'classified': 1,
#          'Trewartha': 1,
#          'scheme': 1,
#          'system': 9,
#          'Summers': 1,
#          'average': 3,
#          'Winters': 1,
#          'Spring': 1,
#          'autumn': 1,
#          'generally': 1,
#          'chilly': 1,
#          'creates': 1,
#          'microclimate': 1,
#          'stored': 1,
#          'buildings': 13,
#          ...})

# %%
# 9. print how often the word 'Berlin' occurs
c['Berlin']
# Out:
# 670

# %%
# 10. print the 10 most common words
c.most_common(10)
# Out:
# [('Berlin', 670),
#  ('Retrieved', 219),
#  ('German', 132),
#  ('parser', 100),
#  ('Germany', 99),
#  ('output', 98),
#  ('Archived', 73),
#  ('original', 69),
#  ('August', 65),
#  ('Brandenburg', 53)]
