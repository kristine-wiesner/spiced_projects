# %% [markdown]
# ### Naive Bayes classifier Exercise

# %%
docs = [
"Its close to midnight", 
"Something evil is lurking from the dark",
"Under the moonlight",
"You see a sight that almost stops your heart",
"You try to scream",
"But terror takes the sound before you make it",
"You start to freeze",
"As horror looks you right between your eyes",
"You are paralyzed",
        
"I could hardly believe it",
"When I heard the news today",
"I had to come and get it straight from you",
"They said you were leaving",
"Someone is swept your heart away",
"From the look upon your face I see its true",
"So tell me all about it",
"Tell me about the plans you are making",
"Then tell me one thing more before I go"]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
import pandas as pd
import numpy as np

# %%
# Instantiate CountVectorizer()
vect = CountVectorizer(stop_words='english')

# Count the word in the corpus
word_count = vect.fit_transform(docs)

# %%
# Instantiate CountVectorizer()
vect
# Out:
# CountVectorizer(stop_words='english')

# %%
# let's check the shape
word_count.shape # <-- Sparse Matrix in Compressed Sparse Row format
# Out:
# (18, 40)

# %% [markdown]
# ### Compute IDF (Inverse Document Frequency)

# %%
# Instantiate TfidfTransformer()
tfidf_tran=TfidfTransformer()

# Fit tfidf_tran
tfidf_tran.fit(word_count)

# print idf values
idf_df = pd.DataFrame(tfidf_tran.idf_, index=vect.get_feature_names(),columns=["idf_weights"])
idf_df.sort_values(by=['idf_weights'])
# Out:
#            idf_weights
# tell          2.558145
# heart         2.845827
# away          3.251292
# paralyzed     3.251292
# plans         3.251292
# right         3.251292
# said          3.251292
# scream        3.251292
# sight         3.251292
# sound         3.251292
# start         3.251292
# stops         3.251292
# straight      3.251292
# swept         3.251292
# takes         3.251292
# terror        3.251292
# thing         3.251292
# today         3.251292
# news          3.251292
# moonlight     3.251292
# midnight      3.251292
# making        3.251292
# believe       3.251292
# close         3.251292
# come          3.251292
# dark          3.251292
# evil          3.251292
# eyes          3.251292
# face          3.251292
# true          3.251292
# freeze        3.251292
# heard         3.251292
# horror        3.251292
# leaving       3.251292
# look          3.251292
# looks         3.251292
# lurking       3.251292
# make          3.251292
# hardly        3.251292
# try           3.251292

# %% [markdown]
# ### Compute the TFIDF score for the corpus

# %%
# transform tfidf_tran --> term frequency inverse document frequency
tfidf_mat=tfidf_tran.transform(word_count)

# %%
tfidf_mat.shape
# Out:
# (18, 40)

# %%
# tfidf_mat --> dense matrix
tfidf_mat = tfidf_mat.todense()

# %%
# tf_idf_mat --> dataframe
indexs = ['doc1','doc2','doc3','doc4','doc5','doc6','doc7','doc8','doc9',
          'doc10', 'doc11','doc12','doc13','doc14','doc15','doc16','doc17', 'doc18' ]
tfid_df = pd.DataFrame(tfidf_mat,columns=vect.get_feature_names(),index=indexs)

# %%
tfid_df
# Out:
#            away   believe     close      come     dark     evil  eyes  \
# doc1   0.000000  0.000000  0.707107  0.000000  0.00000  0.00000   0.0
# doc2   0.000000  0.000000  0.000000  0.000000  0.57735  0.57735   0.0
# doc3   0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc4   0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc5   0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc6   0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc7   0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc8   0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.5
# doc9   0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc10  0.000000  0.707107  0.000000  0.000000  0.00000  0.00000   0.0
# doc11  0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc12  0.000000  0.000000  0.000000  0.707107  0.00000  0.00000   0.0
# doc13  0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc14  0.601261  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc15  0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc16  0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc17  0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
# doc18  0.000000  0.000000  0.000000  0.000000  0.00000  0.00000   0.0
#
#           face    freeze    hardly  ...     stops  straight     swept  takes  \
# doc1   0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc2   0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc3   0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc4   0.00000  0.000000  0.000000  ...  0.601261  0.000000  0.000000    0.0
# doc5   0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc6   0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.5
# doc7   0.00000  0.707107  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc8   0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc9   0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc10  0.00000  0.000000  0.707107  ...  0.000000  0.000000  0.000000    0.0
# doc11  0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc12  0.00000  0.000000  0.000000  ...  0.000000  0.707107  0.000000    0.0
# doc13  0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc14  0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.601261    0.0
# doc15  0.57735  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc16  0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc17  0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
# doc18  0.00000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    0.0
#
#            tell  terror   thing    today     true       try
# doc1   0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc2   0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc3   0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc4   0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc5   0.000000     0.0  0.0000  0.00000  0.00000  0.707107
# doc6   0.000000     0.5  0.0000  0.00000  0.00000  0.000000
# doc7   0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc8   0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc9   0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc10  0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc11  0.000000     0.0  0.0000  0.57735  0.00000  0.000000
# doc12  0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc13  0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc14  0.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc15  0.000000     0.0  0.0000  0.00000  0.57735  0.000000
# doc16  1.000000     0.0  0.0000  0.00000  0.00000  0.000000
# doc17  0.486179     0.0  0.0000  0.00000  0.00000  0.000000
# doc18  0.618353     0.0  0.7859  0.00000  0.00000  0.000000
#
# [18 rows x 40 columns]

# %% [markdown]
# Naive Bayes in Sklearn

# %%
from sklearn.naive_bayes import  MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Artist variable
artist = ['Jackson']*9 + ['Bolton']*9
artist
y = np.array(artist)

# %%
# Features variable
X = tfidf_mat

# %%
# train and test split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.20,random_state=200)

# %%
# Instantiate the model
model = MultinomialNB(alpha=.8)
# fit the model
model.fit(X_train,y_train)
# Out:
# MultinomialNB(alpha=0.8)

# %%
# predict
y_pred = model.predict(X_test)

# %%
print(f'Accuracy test: {accuracy_score(y_test,y_pred):.2}')
# Out:
# Accuracy test: 0.75

# %% [markdown]
# #### What if I want to predict another doc?

# %%
new_doc = ['It is just a dream of mine is coming to an end']
new_doc_vect = vect.transform(new_doc).todense() # <-- use only transform
new_doc_tfidf = tfidf_tran.transform(new_doc_vect).todense() # <-- use only transform

# %%
model.predict(new_doc_tfidf)
# Out:
# array(['Bolton'], dtype='<U7')

# %%
new_doc = ['The evil of the thriller']
new_doc_vect = vect.transform(new_doc).todense() # <-- use only transform
new_doc_tfidf = tfidf_tran.transform(new_doc_vect).todense() # <-- use only transform

# %%
model.predict(new_doc_tfidf)
# Out:
# array(['Jackson'], dtype='<U7')
